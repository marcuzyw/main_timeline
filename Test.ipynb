# %%
from src.ML_Backtester import ML_Backtester

ml = ML_Backtester(symbol="AAPL",start="2015-12-31",end="2020-06-30",tc=0)
# Out:
# c:\Users\marcu\Documents\GitHub\main_timeline\src\ML_Backtester.py:64: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   raw = yf.download(self.symbol,self.start,self.end,multi_level_index=False)
# [*********************100%***********************]  1 of 1 completed

# %%
ml.test_ml_strategy(train_ratio=0.8, lags=5)
# Out:
# ---------------------------------------------------------------------------
# Testing ML strategy | AAPL | lags = 5
# ---------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------
# Finished testing ML strategy | AAPL | lags = 5
# Performance of Strategy = 2.083039, Outperformance = 0.26846
# ---------------------------------------------------------------------------
# (np.float64(2.083039), np.float64(0.26846))

# %%
ml.show_data()
# Out:
#                 Close   returns
# Date
# 2015-12-31  23.755865       NaN
# 2016-01-04  23.776178  0.000855
# 2016-01-05  23.180359 -0.025379
# 2016-01-06  22.726734 -0.019763
# 2016-01-07  21.767557 -0.043121
# ...               ...       ...
# 2020-06-23  88.972137  0.021120
# 2020-06-24  87.401581 -0.017810
# 2020-06-25  88.561905  0.013188
# 2020-06-26  85.840782 -0.031208
# 2020-06-29  87.819138  0.022785
#
# [1131 rows x 2 columns]

# %%
ml.show_results()
# Out:
#                 Close   returns      lag1      lag2      lag3      lag4  \
# Date
# 2019-08-12  48.273655 -0.002540 -0.598179  1.360173  0.612176  1.163733
# 2019-08-13  50.317963  0.041476 -0.224403 -0.594575  1.360313  0.615019
# 2019-08-14  48.820232 -0.030217  2.644697 -0.222068 -0.594857  1.362605
# 2019-08-15  48.577042 -0.004994 -2.028436  2.637291 -0.222269 -0.591122
# 2019-08-16  49.723213  0.023321 -0.384314 -2.019977  2.637708 -0.218810
# ...               ...       ...       ...       ...       ...       ...
# 2020-06-23  88.972137  0.021120  1.624680 -0.429335 -0.031324 -0.144292
# 2020-06-24  87.401581 -0.017810  1.317847  1.620737 -0.429581 -0.028005
# 2020-06-25  88.561905  0.013188 -1.219694  1.314946  1.620933 -0.425968
# 2020-06-26  85.840782 -0.031208  0.800843 -1.213981  1.315077  1.623032
# 2020-06-29  87.819138  0.022785 -2.092985  0.799696 -1.214396  1.317401
#
#                 lag5  prediction  strategy_returns  trades  creturns  \
# Date
# ...

# %%
ml.plot_results()
